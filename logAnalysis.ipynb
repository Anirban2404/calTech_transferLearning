# %%
from collections import defaultdict

computeDict8 = defaultdict()
updateDict8 = defaultdict()
updateMetricDict8 = defaultdict()
prepareDict8 = defaultdict()

computeDict24 = defaultdict()
updateDict24 = defaultdict()
updateMetricDict24 = defaultdict()
prepareDict24 = defaultdict()

# computeDict128 = defaultdict()
# updateDict128 = defaultdict()
# updateMetricDict128 = defaultdict()
# prepareDict128 = defaultdict()

# computeDict64 = defaultdict()
# updateDict64 = defaultdict()
# updateMetricDict64 = defaultdict()
# prepareDict64 = defaultdict()

#f512= open("log512.txt","r")
#f256= open("log256.txt","r")
f8= open("log_8.log","r")
f24= open("log_24.log","r")

for i, x in enumerate(f8.readlines()):    
    if i < 8:
        continue
    else:
        #print(x)
        
        splitArr = x.split()
        if len(splitArr) < 5:
            continue
        if splitArr[2] == "compute":
            computeDict8[int(splitArr[1])] = float(splitArr[4])
        if splitArr[2] == "update" and splitArr[3] == "time:":
            updateDict8[int(splitArr[1])] = float(splitArr[4])
        if splitArr[2] == "update" and splitArr[3] == "metric":
            updateMetricDict8[int(splitArr[1])] = float(splitArr[5])
        if splitArr[2] == "prepare":
            prepareDict8[int(splitArr[1])] = float(splitArr[4])
        #print(splitArr, splitArr[2],splitArr[4])
        
for i, x in enumerate(f24.readlines()):    
    if i < 8:
        continue
    else:
        #print(x)
        
        splitArr = x.split()
        if len(splitArr) < 5:
            continue
        if splitArr[2] == "compute":
            computeDict24[int(splitArr[1])] = float(splitArr[4])
        if splitArr[2] == "update" and splitArr[3] == "time:":
            updateDict24[int(splitArr[1])] = float(splitArr[4])
        if splitArr[2] == "update" and splitArr[3] == "metric":
            updateMetricDict24[int(splitArr[1])] = float(splitArr[5])
        if splitArr[2] == "prepare":
            prepareDict24[int(splitArr[1])] = float(splitArr[4])
        #print(splitArr, splitArr[2],splitArr[4])
        
# for i, x in enumerate(f128.readlines()):    
#     if i < 8:
#         continue
#     else:
#         #print(x)
        
#         splitArr = x.split()
#         if len(splitArr) < 5:
#             continue
#         if splitArr[2] == "compute":
#             computeDict128[int(splitArr[1])] = float(splitArr[4])
#         if splitArr[2] == "update" and splitArr[3] == "time:":
#             updateDict128[int(splitArr[1])] = float(splitArr[4])
#         if splitArr[2] == "update" and splitArr[3] == "metric":
#             updateMetricDict128[int(splitArr[1])] = float(splitArr[5])
#         if splitArr[2] == "prepare":
#             prepareDict128[int(splitArr[1])] = float(splitArr[4])
#         #print(splitArr, splitArr[2],splitArr[4])
        
# for i, x in enumerate(f64.readlines()):    
#     if i < 8:
#         continue
#     else:
#         #print(x)
        
#         splitArr = x.split()
#         if len(splitArr) < 5:
#             continue
#         if splitArr[2] == "compute":
#             computeDict64[int(splitArr[1])] = float(splitArr[4])
#         if splitArr[2] == "update" and splitArr[3] == "time:":
#             updateDict64[int(splitArr[1])] = float(splitArr[4])
#         if splitArr[2] == "update" and splitArr[3] == "metric":
#             updateMetricDict64[int(splitArr[1])] = float(splitArr[5])
#         if splitArr[2] == "prepare":
#             prepareDict64[int(splitArr[1])] = float(splitArr[4])
#         #print(splitArr, splitArr[2],splitArr[4])

# %%
#computeDict
#updateDict
#updateMetricDict
#prepareDict

# %%
import matplotlib.pylab as plt
fig= plt.figure(figsize=(3,6))
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

print(plt.rcParams.get('figure.figsize'))
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 8
plt.rcParams["figure.figsize"] = fig_size
print(plt.rcParams.get('figure.figsize'))
# Out:
# [6.0, 4.0]
# [10.0, 8.0]

# %%
fig, axs = plt.subplots(4, sharex=True, sharey=True)
x, y = zip(*computeDict8.items())
print("Mean:", sum(y)/len(y))
axs[0].plot(x, y, 'r-', linewidth=3)
x, y = zip(*computeDict24.items())
print("Mean:", sum(y)/len(y))
axs[1].plot(x, y, 'y-', linewidth=3)
# x, y = zip(*computeDict128.items())
# print("Mean:", sum(y)/len(y))
# axs[2].plot(x, y, 'g-', linewidth=3)
# x, y = zip(*computeDict64.items())
# print("Mean:", sum(y)/len(y))
# axs[3].plot(x, y, 'b-', linewidth=3)
# Out:
# Mean: 0.7397829664419897
# Mean: 1.9696005671112626

# %%
fig, axs = plt.subplots(4, sharex=True, sharey=True)
x, y = zip(*updateDict8.items())
print("Mean:", sum(y)/len(y))
axs[0].plot(x, y, 'r-', linewidth=3)
x, y = zip(*updateDict24.items())
print("Mean:", sum(y)/len(y))
axs[1].plot(x, y, 'y-', linewidth=3)
# x, y = zip(*updateDict128.items())
# print("Mean:", sum(y)/len(y))
# axs[2].plot(x, y, 'g-', linewidth=3)
# x, y = zip(*updateDict64.items())
# print("Mean:", sum(y)/len(y))
# axs[3].plot(x, y, 'b-', linewidth=3)
# Out:
# Mean: 0.02649153759760886
# Mean: 0.026852616557368526

# %%
fig, axs = plt.subplots(4, sharex=True, sharey=True)
x, y = zip(*updateMetricDict8.items())
print("Mean:", sum(y)/len(y))
axs[0].plot(x, y, 'r-', linewidth=3)
x, y = zip(*updateMetricDict24.items())
print("Mean:", sum(y)/len(y))
axs[1].plot(x, y, 'y-', linewidth=3)
# x, y = zip(*updateMetricDict128.items())
# print("Mean:", sum(y)/len(y))
# axs[2].plot(x, y, 'g-', linewidth=3)
# x, y = zip(*updateMetricDict64.items())
# print("Mean:", sum(y)/len(y))
# axs[3].plot(x, y, 'b-', linewidth=3)
# Out:
# Mean: 0.0026752659993142074
# Mean: 0.0024685506467466

# %%
fig, axs = plt.subplots(4, sharex=True, sharey=True)
x, y = zip(*prepareDict8.items())
print("Mean:", sum(y)/len(y))
axs[0].plot(x, y, 'r-', linewidth=3)
x, y = zip(*prepareDict24.items())
print("Mean:", sum(y)/len(y))
axs[1].plot(x, y, 'y-', linewidth=3)
# x, y = zip(*prepareDict128.items())
# print("Mean:", sum(y)/len(y))
# axs[2].plot(x, y, 'g-', linewidth=3)
# x, y = zip(*prepareDict64.items())
# print("Mean:", sum(y)/len(y))
# axs[3].plot(x, y, 'b-', linewidth=3)
# Out:
# Mean: 0.0004661334967761306
# Mean: 0.0005161320721661603
