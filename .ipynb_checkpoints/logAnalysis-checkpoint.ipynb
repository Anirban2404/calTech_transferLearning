# %%
from collections import defaultdict

computeDict512 = defaultdict()
updateDict512 = defaultdict()
updateMetricDict512 = defaultdict()
prepareDict512 = defaultdict()

computeDict256 = defaultdict()
updateDict256 = defaultdict()
updateMetricDict256 = defaultdict()
prepareDict256 = defaultdict()

computeDict128 = defaultdict()
updateDict128 = defaultdict()
updateMetricDict128 = defaultdict()
prepareDict128 = defaultdict()

computeDict64 = defaultdict()
updateDict64 = defaultdict()
updateMetricDict64 = defaultdict()
prepareDict64 = defaultdict()

#f512= open("log512.txt","r")
#f256= open("log256.txt","r")
f8= open("log8.txt","r")
f64= open("log64.txt","r")

for i, x in enumerate(f512.readlines()):    
    if i < 8:
        continue
    else:
        #print(x)
        
        splitArr = x.split()
        if len(splitArr) < 5:
            continue
        if splitArr[2] == "compute":
            computeDict512[int(splitArr[1])] = float(splitArr[4])
        if splitArr[2] == "update" and splitArr[3] == "time:":
            updateDict512[int(splitArr[1])] = float(splitArr[4])
        if splitArr[2] == "update" and splitArr[3] == "metric":
            updateMetricDict512[int(splitArr[1])] = float(splitArr[5])
        if splitArr[2] == "prepare":
            prepareDict512[int(splitArr[1])] = float(splitArr[4])
        #print(splitArr, splitArr[2],splitArr[4])
        
for i, x in enumerate(f256.readlines()):    
    if i < 8:
        continue
    else:
        #print(x)
        
        splitArr = x.split()
        if len(splitArr) < 5:
            continue
        if splitArr[2] == "compute":
            computeDict256[int(splitArr[1])] = float(splitArr[4])
        if splitArr[2] == "update" and splitArr[3] == "time:":
            updateDict256[int(splitArr[1])] = float(splitArr[4])
        if splitArr[2] == "update" and splitArr[3] == "metric":
            updateMetricDict256[int(splitArr[1])] = float(splitArr[5])
        if splitArr[2] == "prepare":
            prepareDict256[int(splitArr[1])] = float(splitArr[4])
        #print(splitArr, splitArr[2],splitArr[4])
        
# for i, x in enumerate(f128.readlines()):    
#     if i < 8:
#         continue
#     else:
#         #print(x)
        
#         splitArr = x.split()
#         if len(splitArr) < 5:
#             continue
#         if splitArr[2] == "compute":
#             computeDict128[int(splitArr[1])] = float(splitArr[4])
#         if splitArr[2] == "update" and splitArr[3] == "time:":
#             updateDict128[int(splitArr[1])] = float(splitArr[4])
#         if splitArr[2] == "update" and splitArr[3] == "metric":
#             updateMetricDict128[int(splitArr[1])] = float(splitArr[5])
#         if splitArr[2] == "prepare":
#             prepareDict128[int(splitArr[1])] = float(splitArr[4])
#         #print(splitArr, splitArr[2],splitArr[4])
        
# for i, x in enumerate(f64.readlines()):    
#     if i < 8:
#         continue
#     else:
#         #print(x)
        
#         splitArr = x.split()
#         if len(splitArr) < 5:
#             continue
#         if splitArr[2] == "compute":
#             computeDict64[int(splitArr[1])] = float(splitArr[4])
#         if splitArr[2] == "update" and splitArr[3] == "time:":
#             updateDict64[int(splitArr[1])] = float(splitArr[4])
#         if splitArr[2] == "update" and splitArr[3] == "metric":
#             updateMetricDict64[int(splitArr[1])] = float(splitArr[5])
#         if splitArr[2] == "prepare":
#             prepareDict64[int(splitArr[1])] = float(splitArr[4])
#         #print(splitArr, splitArr[2],splitArr[4])

# %%
#computeDict
#updateDict
#updateMetricDict
#prepareDict

# %%
import matplotlib.pylab as plt
fig= plt.figure(figsize=(3,6))
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

print(plt.rcParams.get('figure.figsize'))
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 8
plt.rcParams["figure.figsize"] = fig_size
print(plt.rcParams.get('figure.figsize'))
# Out:
# [6.0, 4.0]
# [10.0, 8.0]

# %%
fig, axs = plt.subplots(4, sharex=True, sharey=True)
x, y = zip(*computeDict512.items())
print("Mean:", sum(y)/len(y))
axs[0].plot(x, y, 'r-', linewidth=3)
x, y = zip(*computeDict256.items())
print("Mean:", sum(y)/len(y))
axs[1].plot(x, y, 'y-', linewidth=3)
x, y = zip(*computeDict128.items())
print("Mean:", sum(y)/len(y))
axs[2].plot(x, y, 'g-', linewidth=3)
x, y = zip(*computeDict64.items())
print("Mean:", sum(y)/len(y))
axs[3].plot(x, y, 'b-', linewidth=3)
# Out:
# Mean: 3.5532438876677532
# Mean: 1.9979761036074892
# Mean: 1.0830881656588192
# Mean: 0.5751919749447757

# %%
fig, axs = plt.subplots(4, sharex=True, sharey=True)
x, y = zip(*updateDict512.items())
print("Mean:", sum(y)/len(y))
axs[0].plot(x, y, 'r-', linewidth=3)
x, y = zip(*updateDict256.items())
print("Mean:", sum(y)/len(y))
axs[1].plot(x, y, 'y-', linewidth=3)
x, y = zip(*updateDict128.items())
print("Mean:", sum(y)/len(y))
axs[2].plot(x, y, 'g-', linewidth=3)
x, y = zip(*updateDict64.items())
print("Mean:", sum(y)/len(y))
axs[3].plot(x, y, 'b-', linewidth=3)
# Out:
# Mean: 0.12336249010903495
# Mean: 0.11874991290423335
# Mean: 0.11502060134087683
# Mean: 0.11369712547877865

# %%
fig, axs = plt.subplots(4, sharex=True, sharey=True)
x, y = zip(*updateMetricDict512.items())
print("Mean:", sum(y)/len(y))
axs[0].plot(x, y, 'r-', linewidth=3)
x, y = zip(*updateMetricDict256.items())
print("Mean:", sum(y)/len(y))
axs[1].plot(x, y, 'y-', linewidth=3)
x, y = zip(*updateMetricDict128.items())
print("Mean:", sum(y)/len(y))
axs[2].plot(x, y, 'g-', linewidth=3)
x, y = zip(*updateMetricDict64.items())
print("Mean:", sum(y)/len(y))
axs[3].plot(x, y, 'b-', linewidth=3)
# Out:
# Mean: 0.0028336023797794264
# Mean: 0.003221815946150799
# Mean: 0.0026683642736176397
# Mean: 0.002691123796545941

# %%
fig, axs = plt.subplots(4, sharex=True, sharey=True)
x, y = zip(*prepareDict512.items())
print("Mean:", sum(y)/len(y))
axs[0].plot(x, y, 'r-', linewidth=3)
x, y = zip(*prepareDict256.items())
print("Mean:", sum(y)/len(y))
axs[1].plot(x, y, 'y-', linewidth=3)
x, y = zip(*prepareDict128.items())
print("Mean:", sum(y)/len(y))
axs[2].plot(x, y, 'g-', linewidth=3)
x, y = zip(*prepareDict64.items())
print("Mean:", sum(y)/len(y))
axs[3].plot(x, y, 'b-', linewidth=3)
# Out:
# Mean: 0.0005936330678511639
# Mean: 0.0005996811146638831
# Mean: 0.0005753454954727837
# Mean: 0.0005563625594234222
